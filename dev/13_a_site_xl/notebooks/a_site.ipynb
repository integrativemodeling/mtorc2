# %%
import pandas as pd
from pathlib import Path

# %%
models_dir = Path(Path.home(), "Documents/mtorc2/manuscript/submission/models")
main_xl_file = Path(models_dir, "119_6_2_2/cluster.0/xls_new.csv")
a_xl_file = Path(models_dir, "89_2462_1_8525/xls_corr.csv")

# %%
main_xl_df = pd.read_csv(main_xl_file)
main_xl_df = main_xl_df.drop(columns=["Unnamed: 0"])

a_xl_df = pd.read_csv(a_xl_file)
a_xl_df = a_xl_df.drop(columns=["Unnamed: 0"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main_xl_df = pd.read_csv(main_xl_file)
#       2 main_xl_df = main_xl_df.drop(columns=["Unnamed: 0"])
#       4 a_xl_df = pd.read_csv(a_xl_file)
#
# File ~/opt/anaconda3/envs/imp_220/lib/python3.12/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/imp_220/lib/python3.12/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/opt/anaconda3/envs/imp_220/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/imp_220/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/opt/anaconda3/envs/imp_220/lib/python3.12/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/matthew/Documents/mtorc2/manuscript/submission/models/119_6_2_2/cluster.0/xls_new.csv'

# %%
main_xl_df.head()
# Out:
#     prot1  res1   prot2  res2 type  cutoff  sat   min_dist  ambig frame
# 0    MTOR  1197  RICTOR   516  dss      35    1  10.187430      0  B753
# 1    MTOR  1218  RICTOR   516  dss      35    1   9.649200      0  B220
# 2  RICTOR  1642   MSIN1   102  dss      35    1  15.206493      0  B786
# 3  RICTOR  1092    MTOR  1993  dss      35    0  42.520389      0  B222
# 4  RICTOR  1642   MSIN1   104  dss      35    1  17.592040      0  B786

# %%
a_xl_df.head()
# Out:
#   prot1  res1   prot2  res2 type  cutoff  sat   min_dist  ambig  frame
# 0  MTOR  1197  RICTOR   516  dss      35    1   9.171180      0  B4758
# 1  MTOR  1218  RICTOR   516  dss      35    1   6.640694      0  A2974
# 2  MTOR  1993  RICTOR  1092  dss      35    1  29.576386      0    A79
# 3  MTOR  1186  RICTOR   516  dss      35    1   9.864641      0    A51
# 4  MTOR  2045  RICTOR  1477  dss      35    1   7.712952      0  A3247

# %%
for i in range(len(main_xl_df)):
    prot1, res1, prot2, res2 = main_xl_df.iloc[i, 0:4]

    sat = main_xl_df.iloc[i, main_xl_df.columns.get_loc("sat")]

    if not sat:
#         print(prot1, res1, prot2, res2)
        a_xl_entry = a_xl_df[(a_xl_df["prot1"] == prot1) & (a_xl_df["res1"] == res1) & (a_xl_df["prot2"] == prot2) & (a_xl_df["res2"] == res2)]
        if len(a_xl_entry) == 0:
            a_xl_entry = a_xl_df[(a_xl_df["prot1"] == prot2) & (a_xl_df["res1"] == res2) & (a_xl_df["prot2"] == prot1) & (a_xl_df["res2"] == res1)]

        if len(a_xl_entry) > 0:
            min_dist = float(a_xl_entry["min_dist"])
            a_sat = int(a_xl_entry["sat"])
            print(prot1, res1, prot2, res2, a_sat, min_dist)
        #         a_sat = a_xl_entry["sat"]
#         if a_sat:
#             print(prot1, res1, prot2, res2, sat)
# Out:
# RICTOR 1092 MTOR 1993 1 29.57638550870735
# AKT1 30 RICTOR 813 1 0.0
# AKT1 189 MTOR 533 1 6.13930969984291
# RICTOR 1590 MSIN1 104 1 7.224868504236735
# AKT1 182 RICTOR 516 1 8.676887019849957
# RICTOR 719 AKT1 163 1 9.709106661789884
# MTOR 1256 AKT1 420 1 9.303383558076543
# RICTOR 813 AKT1 163 1 5.527743119652679
# RICTOR 699 MTOR 84 0 87.3122619116863
# MTOR 309 MSIN1 132 0 103.43672662352341
# MSIN1 317 RICTOR 1095 1 5.830003634712926
# MTOR 42 AKT1 284 1 12.718358668010644
# MTOR 2090 AKT1 189 1 32.91184613351687
# AKT1 276 RICTOR 800 1 21.43370842604891
# RICTOR 566 MSIN1 317 0 50.972190445618715
# MTOR 298 MTOR 1745 0 62.62823084196245
# MTOR 309 MTOR 2370 0 81.48633276701524
# MSIN1 166 MLST8 307 1 3.517174634361104
# MTOR 1457 MSIN1 422 1 12.214815141940324
# MTOR 1766 RICTOR 586 0 133.19822006132605
# RICTOR 545 AKT1 163 1 6.309180942257826
# RICTOR 126 MTOR 2370 0 53.774330534122065

# %%
a_xl_df[(a_xl_df["prot1"] == "RICTOR") & (a_xl_df["res1"] == 719) & (a_xl_df["prot2"] == "AKT1") & (a_xl_df["res2"] == res2)]
# Out:
# Empty DataFrame
# Columns: [prot1, res1, prot2, res2, type, cutoff, sat, min_dist, ambig, frame]
# Index: []
