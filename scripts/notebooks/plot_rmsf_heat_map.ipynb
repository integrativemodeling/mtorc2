# %%
from pathlib import Path 
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
rmsf_file = Path(Path.home(), "Documents/mtorc2/manuscript/submission_2/models/126_0_2_3/cluster.0.rmsf.npy")
rmsf_mat = np.load(rmsf_file)

fig_file = Path(Path.home(), "Documents/mtorc2/manuscript/submission_2/figures/rmsf/rmsf.png")

# %%
figure(figsize=(40, 32), dpi=160)

sns.heatmap(rmsf_mat, square=True, cmap="viridis")

plt.savefig(fig_file)

# %%
rmf_file = Path(Path.home(), "Documents/mtorc2/")
fh = RMF.open_rmf_file_read_only(str(rmf_file))
m = IMP.Model()
h = IMP.rmf.create_hierarchies(fh, m)[0]
IMP.rmf.load_frame(fh, 7355)
